-- %%
%python
delta internals

-- %%
use catalog lakehouse;

-- %%
create schema lakehouse.shanthapriya managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/shanthapriya'

-- %%
create schema if not exists lakehouse.shanthapriya managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/shanthapriya'

-- %%
create table lakehouse.shanthapriya.demo (id int, name string)

-- %% [markdown]
-- #delta internals

-- %%
desc extended lakehouse.shanthapriya.demo
